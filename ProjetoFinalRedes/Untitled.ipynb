# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x = [i for i in range(1,6)]
y = [i for i in range(1,6)]
r = [100 for i in range(1,6)]
fig, ax = plt.subplots(1,1)
ax.scatter(x, y, s=r)
ax.scatter(2, 3, s=13950, alpha=0.4)
ax.grid()
ax.set_aspect("equal")
ax.set_title("Nós")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
